# %% [markdown]
# <a href="https://colab.research.google.com/github/italomellors/Data_Analysis_Projects/blob/main/SuperMarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Market System Simulation with Database
# **“Automating decisions and data with intelligence — from inventory to revenue.”**
#
# **👨🏻‍💻 Developed by: Ítalo de Mello Rodrigues da Silva**
#
# **📧 Email: italomello.ie@gmail.com**
#
# **🌐 GitHub: github.com/italomellors**
#
# **💼 LinkedIn: linkedin.com/in/italomellors**
#
# **📍 Location: Cork city, County cork, Ireland**
#
# **📁 Area of ​​Interest: Data Analysis | Data Engineering | Business
# Intelligence**
#
# ---
# **The complete cycle and the relationship between the market database tables:**
#
# ![Super Market stucture 1.jpg](data:image/jpeg;base64,...)
#
# **Simplified cycle:**
#
# *(Revenue → Expense → Stock Purchase → Products → Sales → Revenue)*
#
# ---
# 1. **Introduction**
#
#  This project aims to create a system that simulates the basic functioning of a market, using the Python programming language, the SQLite database, and visualizations in Power BI. The data is manipulated and analyzed through notebooks in Google Colab, and the entire project is versioned and documented in GitHub. The proposal is to represent the financial and operational cycle of a market in an automated way, allowing queries, performance analysis and visualization of data in a clear and professional way.
#
# 2. **Objectives**
#
#  • Create a relational database in SQLite that represents the cyclical functioning of a market.
#
#  • Use Python for data manipulation, automation and analysis.
#
#  • Visualize data through interactive dashboards in Power BI.
#
#  • Run and share notebooks in the cloud using Google Colab.
#
#  • Document and version the code with Git and GitHub.
#
#  • Simulate revenue, expense, inventory and sales processes.
#
#  • Allow analyses and insights based on recorded data.
#
# 3. **Technologies Used**
#
#  • Python: Main language for development, automation and data analysis.
#
#  • SQLite (sqlite3): Lightweight relational database integrated with Python.
#
#  • SQL: Used to create tables, insert and query data in the database.
#
#  • Power BI: Business Intelligence tool for data visualization and dashboards.
#
#  • Google Colab: Collaborative cloud environment for development with Python and notebooks.
#
#  • Git & GitHub: Version control and hosting of source code and project documentation.
#
#  • Pandas / NumPy: Libraries for processing and analyzing tabular and numerical data.
#
# 4. **Structure and Operation**
#
#  *(Revenue → Expense → Stock Purchase → Products → Sales → Revenue)*
#
#  4.1 Initial Capital
#
#  The system starts with a value of $100.000.00 entered in the Revenue table, representing the capital available in the market's cash register.
#
#  4.2 Expense Generation
#
#  Expenses are automatically generated based on the available capital and recorded in the Expense table.
#
#  4.3 Inventory Purchases
#
#  These expenses feed the Inventory Purchase table, which records the products purchased (type, price, quantity). They are entered in the Available Products table, with the final price already calculated based on the defined profit margin.
#
#  4.4 Sales Simulation
#  Through Python automation, the system generates simulated sales (invoices). These transactions are analyzed and the data is returned to the Revenue table, closing the cycle.
#
#  4.5 Operational Cycle
#  The cycle (Revenue → Expense → Stock Purchase → Products → Sales → Revenue) is continuous and can be executed as many times as necessary, simulating the financial and operational flow of a real market.
#
# 5. **Data Analysis and Visualization**
#
#   After executing one or more cycles, it is possible to perform:
#
#  • SQL queries directly in the database;
#
#  • Profitability analysis by product and category;
#
#  • Identification of best-selling products;
#
#  • Assessment of gross and net profit by period;
#
#  • Dynamic visualizations in Power BI dashboards.
#
# 6. **Expansion Possibilities**
#
#  This project is flexible and can be adapted to different types of businesses and scenarios, such as:
#
#  • Online stores or e-commerce;
#
#  • Pharmacies and drugstores;
#
#  • Restaurants and food trucks;
#
#  • Stocks of micro and small businesses.
#
# 7. **Conclusion**
#
#  This project demonstrates, in practice, the integrated application of Python, SQL, Power BI, Google Colab and GitHub to solve a real problem: simulating the complete cycle of operations and analysis of a market. More than a simple technical exercise, it is a structured, automated and analytical construction that connects raw data to business insights.
#  By developing this system, I exercised fundamental skills for a career in Data Analysis, such as:
#  • Data modeling,
#
#  •Process automation with Python,
#
#  •Querying and manipulation with SQL,
#
#  •Strategic visualization in Power BI,
#
#  •and collaborative organization of projects with GitHub.
#
#  This project is ripe for expansion or adaptation, and showcases my ability to understand, structure, and communicate data with clarity and business value — essential for any data-driven company.

# %% [markdown]
# ---

# %% [markdown]
# #👨‍💻 Starting: every time you open the notebook
#
# 🌐 1. Mount Google Drive: drive.mount('/content/drive')
#
# 📁 2. Set the database path in Drive
#
# 🔌 3. Connect to the SQLite database: con = sqlite3.connect(database_path)
#
# 📚 4. Import the libraries (pandas, sqlite3, os, etc.)
#
# ⚠️ Make sure con.close() is commented out at the end to avoid disconnection during full execution

# %% [markdown]
# # Create and Connect DataBase: SuperMarket.db 🛢🖧🌐

# %% [markdown]
# **🌐Step 1 - Mount Google Drive (always when opening the notebook):**
#
#    Connects your Google Drive to Colab to access and save files directly, such as the SQLite database.

# %%
from google.colab import drive  # Importa a função para conectar o Google Drive no Colab
drive.mount('/content/drive')   # Monta o Drive no diretório /content/drive para acesso aos arquivos
# Out:
# Mounted at /content/drive

# %% [markdown]
# **🗂️ Step 2 – Define the database path in Drive (always after mounting Drive):**
#
# We specify the path where the super_market.db file will be saved and ensure that the folder exists in Google Drive.

# %%
import os  # Biblioteca para manipular caminhos e pastas no sistema operacional
database_path = '/content/drive/MyDrive/ColabNotebooks/SuperMarket/SuperMarket.db'  # Caminho completo do banco no Drive
os.makedirs(os.path.dirname(database_path), exist_ok=True)  # Cria a pasta se ainda não existir

# %% [markdown]
# **🛢 Step 3 – Connect to the SQLite database (always after defining the path):**
#
# Establishes the connection to the super_market.db database in Drive. If the file does not exist, it will be created automatically.

# %%
import sqlite3  # Biblioteca para trabalhar com bancos SQLite em Python
con = sqlite3.connect(database_path) # Conecta ao banco usando o caminho definido
con.execute('PRAGMA foreign_keys = ON;') # Ativa a verificação de chaves estrangeiras
cursor = con.cursor() # Cria um cursor para executar comandos SQL

# %% [markdown]
# **📚 Step 4 - Importing essential libraries:**
#
# These libraries are used throughout the notebook for data analysis, visualization, and manipulation.

# %%
# Lista de bibiliotecas python
from google.colab import drive            # Importa a função para conectar o Google Drive no Colab
import os                                 # Operações com arquivos e diretórios
import sqlite3                            # Conexão e comandos SQL com banco SQLite
import pandas as pd                       # Manipulação de dados com DataFrames
import csv                                # Leitura e escrita de arquivos CSV
import xml.etree.ElementTree as ET        # Para ler, editar e criar arquivos XML
from bs4 import BeautifulSoup             # útil para XMLs não tão bem formatados
import matplotlib.pyplot as plt           # Visualização de dados
import seaborn as sns
import random                    # Visualização de dados
from random import randint                # Numeros aleatorios
from datetime import datetime, timedelta  # Ferramenta de datas

# %% [markdown]
# # Automation functions with Python ⚙️🐍⬇

# %% [markdown]
# # Integration with user Input 🧑‍💻

# %% [markdown]
# # Initial Information 🛒 🔜

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: Revenue 📈💵

# %% [markdown]
# # Insert Into: Revenue ↪

# %% [markdown]
# # Update: Revenue 🔄

# %% [markdown]
# # Select: Revenue ✅

# %% [markdown]
# # Information: Revenue ⟶ FinancialMarket 📑

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: FinancialMarket 📈💰📊

# %% [markdown]
# # Insert Into: FinancialMarket ↪

# %% [markdown]
# # Update: FinancialMarket  🔄

# %% [markdown]
# # Select: FinancialMarket  ✅

# %% [markdown]
# # Table Relationship: Revenue 🔗 FinancialMarket

# %% [markdown]
# # Information: FinancialMarket  ⟶ Expense 📑

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: Expense 💸📉

# %% [markdown]
# # Insert Into: Expense  ↪

# %% [markdown]
# # Update: Expense  🔄

# %% [markdown]
# # Select: Expense  ✅

# %% [markdown]
# # Table Relationship: FinancialMarket 🔗 Expense

# %% [markdown]
# # Information: Expense  ⟶ StockPurchases 📑

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: StockPurchases 📦 𝄃𝄃𝄂𝄀𝄁𝄃𝄂𝄂𝄃

# %% [markdown]
# # Insert Into: StockPurchases  ↪

# %% [markdown]
# # Update: StockPurchases  🔄

# %% [markdown]
# # Select: StockPurchases  ✅

# %% [markdown]
# # Table Relationship: Expense  🔗 StockPurchases

# %% [markdown]
# # Information: StockPurchases  ⟶ AvailableProducts 📑

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: AvailableProducts 🏷️

# %% [markdown]
# # Insert Into: AvailableProducts ↪

# %% [markdown]
# # Update: AvailableProducts  🔄

# %% [markdown]
# # Select: AvailableProducts  ✅

# %% [markdown]
# # Table Relationship: StockPurchases  🔗 AvailableProducts

# %% [markdown]
# # Information: AvailableProducts  ⟶ SalesReceipt 📑

# %% [markdown]
# ---

# %% [markdown]
# # Create Table: SalesReceipt 📃

# %% [markdown]
# # Insert Into: SalesReceipt ↪

# %% [markdown]
# # Update: SalesReceipt  🔄

# %% [markdown]
# # Select: SalesReceipt  ✅

# %% [markdown]
# # Table Relationship: SalesReceipt  🔗 SalesReceipt

# %% [markdown]
# # Information: SalesReceipt  ⟶ Revenue 📑↑

# %% [markdown]
# ---

# %% [markdown]
# # Relationship_AllTables 🖧

# %% [markdown]
# # Saving and disconnecting the database 💾🔌

# %% [markdown]
# **Saving changes to the database:** 💾
#
# We run `con.commit()` to commit the changes and ensure that the data is saved permanently.

# %%
con.commit()
print("✅ Data successfully imported into SQLite database!")

# %% [markdown]
# **Execute this cell ONLY when you have finished all work with the database. remove comments (#) 🔒**
#
# Close the connection to the database 🔌
# We close the connection to SQLite after finishing the operations, freeing up system resources.

# %%
#🔒 Fechar conexão com o banco de dados (só executar ao finalizar tudo)
#Use esta célula apenas quando terminar TODAS as edições e inserções no banco
con.close()
print("✅ Database disconnected successfully.")

# %% [markdown]
# # Conclusion 🔚
